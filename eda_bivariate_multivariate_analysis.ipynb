# %%
import seaborn as sns

# %%
import pandas as pd

# %%
tips = sns.load_dataset('tips')

# %%
titanic = sns.load_dataset('titanic')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(tips['total_bill'],tips['tip'])
# Out:
# /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(tips['total_bill'],tips['tip'],hue = tips['sex'],style=tips['smoker'])
# Out:
# /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.distplot(titanic[titanic['survived']==0]['age'],hist=False)
sns.distplot(titanic[titanic['survived']==1]['age'],hist=False)
# Out:
# /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue = 'species')

# %%
iris = sns.load_dataset('iris')

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.5.0-py2.py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 123 kB/s eta 0:00:01
# Collecting htmlmin==0.1.12
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (679 kB)
#      |████████████████████████████████| 679 kB 571 kB/s eta 0:00:01
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      |████████████████████████████████| 102 kB 3.1 MB/s eta 0:00:01
# Requirement already satisfied: requests<2.29,>=2.24.0 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from pandas-profiling) (2.27.1)
# Collecting multimethod<1.10,>=1.4
#   Downloading multimethod-1.9-py3-none-any.whl (10 kB)
# Collecting typeguard<2.14,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from pandas-profiling) (3.5.2)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from pandas-profiling) (1.22.4)
# Collecting pydantic<1.11,>=1.8.1
#   Downloading pydantic-1.10.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.2 MB)
#      |████████████████████████████████| 13.2 MB 5.4 MB/s eta 0:00:01
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from pandas-profiling) (1.4.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from pandas-profiling) (0.11.2)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from pandas-profiling) (0.13.2)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from pandas-profiling) (1.8.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from pandas-profiling) (3.0.3)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from pandas-profiling) (4.64.0)
# Collecting tangled-up-in-unicode>=0.0.4
#   Using cached tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Collecting networkx>=2.4
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 6.3 MB/s eta 0:00:01
# Requirement already satisfied: attrs>=19.3.0 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (21.4.0)
# Collecting imagehash
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      |████████████████████████████████| 296 kB 6.4 MB/s eta 0:00:01
# Requirement already satisfied: Pillow in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (9.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->pandas-profiling) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (4.33.3)
# Requirement already satisfied: pytz>=2020.1 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from pandas!=1.4.0,<1.6,>1.1->pandas-profiling) (2021.3)
# Requirement already satisfied: joblib>=0.14.1 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->pandas-profiling) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from pydantic<1.11,>=1.8.1->pandas-profiling) (4.1.1)
# Requirement already satisfied: six>=1.5 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib<3.7,>=3.2->pandas-profiling) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (1.26.9)
# Requirement already satisfied: patsy>=0.5.2 in /home/payal/anaconda3/envs/learn_python/lib/python3.9/site-packages (from statsmodels<0.14,>=0.13.2->pandas-profiling) (0.5.2)
# Collecting PyWavelets
#   Downloading PyWavelets-1.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 4.3 MB/s eta 0:00:01
# Installing collected packages: tangled-up-in-unicode, PyWavelets, networkx, multimethod, visions, imagehash, typeguard, pydantic, phik, htmlmin, pandas-profiling
# Successfully installed PyWavelets-1.4.1 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.9 networkx-2.8.8 pandas-profiling-3.5.0 phik-0.12.3 pydantic-1.10.2 tangled-up-in-unicode-0.2.0 typeguard-2.13.3 visions-0.7.5
